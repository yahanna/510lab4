# %%
import sqlite3
conn = sqlite3.connect('world.db')
import requests

cursor = conn.cursor()

create_locations_table_query = """
    CREATE TABLE IF NOT EXISTS locations (
        location_id INTEGER PRIMARY KEY AUTOINCREMENT,
        city_name TEXT NOT NULL,
        country TEXT NOT NULL,
        timezone TEXT NOT NULL
    );
    """
cursor.execute(create_locations_table_query)
create_finance_data_table_query = """
    CREATE TABLE IF NOT EXISTS finance_data (
        data_id INTEGER PRIMARY KEY AUTOINCREMENT,
        location_id INTEGER,
        stock_price REAL,
        forex_rate REAL,
        bitcoin_price REAL,
        timestamp DATETIME DEFAULT CURRENT_TIMESTAMP,
        FOREIGN KEY(location_id) REFERENCES locations(location_id)
    );
    """
cursor.execute(create_finance_data_table_query)
    # 创建weather_data表
create_weather_data_table_query = """
    CREATE TABLE IF NOT EXISTS weather_data (
        weather_id INTEGER PRIMARY KEY AUTOINCREMENT,
        location_id INTEGER,
        temperature REAL,
        humidity INTEGER,
        weather_description TEXT,
        timestamp DATETIME DEFAULT CURRENT_TIMESTAMP,
        FOREIGN KEY(location_id) REFERENCES locations(location_id)
    );
    """
cursor.execute(create_weather_data_table_query)

    # 创建emergency_calls表
create_emergency_calls_table_query = """
    CREATE TABLE IF NOT EXISTS emergency_calls (
        call_id INTEGER PRIMARY KEY AUTOINCREMENT,
        location_id INTEGER,
        call_type TEXT,
        description TEXT,
        timestamp DATETIME DEFAULT CURRENT_TIMESTAMP,
        FOREIGN KEY(location_id) REFERENCES locations(location_id)
    );
    """
cursor.execute(create_emergency_calls_table_query)

conn.commit()
conn.close()

# %%
import requests
def fetch_and_store_weather_data(api_key, city_name, country):
    # 构造请求URL
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name},{country}&appid={api_key}&units=metric"

    response = requests.get(url)
    weather_data = response.json()

    # 解析天气数据
    temperature = weather_data["main"]["temp"]
    humidity = weather_data["main"]["humidity"]
    weather_description = weather_data["weather"][0]["description"]

    # 连接到数据库
    conn = sqlite3.connect('world.db')
    cursor = conn.cursor()

    # 插入数据到weather_data表
    insert_query = """
        INSERT INTO weather_data (location_id, temperature, humidity, weather_description)
        VALUES ((SELECT location_id FROM locations WHERE city_name = ? AND country = ?), ?, ?, ?);
    """
    cursor.execute(insert_query, (city_name, country, temperature, humidity, weather_description))
    
    # 提交并关闭连接
    conn.commit()
    conn.close()

# 假设这是你的API密钥和城市信息
api_key = "d1bdfd06881bbff02296606bc8a6ce9b"  # 使用你的实际API密钥替换这里
def fetch_and_store_weather_data(api_key, city_name, country):
    # 构造请求URL
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name},{country}&appid={api_key}&units=metric"

    response = requests.get(url)
    weather_data = response.json()
def fetch_and_store_weather_data(api_key, city_name, country):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name},{country}&appid={api_key}&units=metric"

    # 发送请求
    response = requests.get(url)
    if response.status_code != 200:
        # 如果响应状态码不是200，打印状态码和错误信息
        print(f"Error fetching weather data: Status code {response.status_code}")
        print(response.text)
        return

    weather_data = response.json()

    # 打印响应内容以便调试
    print(weather_data)

    # 确保响应中包含所需的数据，然后再访问它们
    if 'main' in weather_data and 'weather' in weather_data and len(weather_data['weather']) > 0:
        temperature = weather_data["main"]["temp"]
        humidity = weather_data["main"]["humidity"]
        weather_description = weather_data["weather"][0]["description"]
        
        # 连接到数据库...
        # 省略数据库操作代码，保持不变
    else:
        print("Required data not in response")

    
api_key = "d1bdfd06881bbff02296606bc8a6ce9b"
fetch_and_store_weather_data(api_key, "London", "UK")
# Out:
# Error fetching weather data: Status code 401
# {"cod":401, "message": "Invalid API key. Please see https://openweathermap.org/faq#error401 for more info."}

# %%
import requests
import sqlite3

def fetch_and_store_weather_data(api_key, city_name, country, lat, lon):
    url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}&units=metric"

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching weather data: Status code {response.status_code}")
        print(response.text)
        return

    weather_data = response.json()

    # 根据API字段解析数据
    temperature = weather_data["main"]["temp"]
    humidity = weather_data["main"]["humidity"]
    weather_description = weather_data["weather"][0]["description"]

    # 连接到数据库
    conn = sqlite3.connect('world.db')
    cursor = conn.cursor()

    # 插入数据到weather_data表
    # 假设你已经有了对应城市的location_id
    insert_query = """
        INSERT INTO weather_data (location_id, temperature, humidity, weather_description)
        VALUES ((SELECT location_id FROM locations WHERE city_name = ? AND country = ?), ?, ?, ?);
    """
    cursor.execute(insert_query, (city_name, country, temperature, humidity, weather_description))
    
    conn.commit()
    conn.close()

# 示例使用
api_key = "YOUR_API_KEY"  # 替换为你的API密钥
fetch_and_store_weather_data(api_key, "Modena", "IT", 44.34, 10.99)
# Out:
# Error fetching weather data: Status code 401
# {"cod":401, "message": "Invalid API key. Please see https://openweathermap.org/faq#error401 for more info."}

# %%
# 解析天气数据
    temperature = weather_data["main"]["temp"]
    humidity = weather_data["main"]["humidity"]
    weather_description = weather_data["weather"][0]["description"]

    # 连接到数据库
    conn = sqlite3.connect('world.db')
    cursor = conn.cursor()

    # 插入数据到weather_data表
    insert_query = """
        INSERT INTO weather_data (location_id, temperature, humidity, weather_description)
        VALUES ((SELECT location_id FROM locations WHERE city_name = ? AND country = ?), ?, ?, ?);
    """
    cursor.execute(insert_query, (city_name, country, temperature, humidity, weather_description))
    
    # 提交并关闭连接
    conn.commit()
    conn.close()

# 假设这是你的API密钥和城市信息

# %%
def fetch_and_store_weather_data(api_key, city_name, country):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name},{country}&appid={api_key}&units=metric"

    # 发送请求
    response = requests.get(url)
    if response.status_code != 200:
        # 如果响应状态码不是200，打印状态码和错误信息
        print(f"Error fetching weather data: Status code {response.status_code}")
        print(response.text)
        return

    weather_data = response.json()

    # 打印响应内容以便调试
    print(weather_data)

    # 确保响应中包含所需的数据，然后再访问它们
    if 'main' in weather_data and 'weather' in weather_data and len(weather_data['weather']) > 0:
        temperature = weather_data["main"]["temp"]
        humidity = weather_data["main"]["humidity"]
        weather_description = weather_data["weather"][0]["description"]
        
        # 连接到数据库...
        # 省略数据库操作代码，保持不变
    else:
        print("Required data not in response")

# %%
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim


def get_weather(latitude, longitude):

    url = f"https://api.weather.gov/points/{latitude},{longitude}"
    res = requests.get(url)
    data = res.json()
    forecast_url = data['properties']['forecast']
    forecast_res = requests.get(forecast_url)
    forecast_data = forecast_res.json()
    temperature = forecast_data['properties']['periods'][0]['temperature']
    return temperature

import sqlite3

def store_weather_data(latitude, longitude):
    # 首先，获取温度
    temperature = get_weather(latitude, longitude)

    # 连接到SQLite数据库
    conn = sqlite3.connect('world.db')
    cursor = conn.cursor()

    # 插入数据到weather_data表
    # 假设我们为每个独特的纬度和经度对创建了一个虚拟的location_id
    # 或者你可以根据需要调整此查询来匹配你的数据库结构
    
    insert_query = """
        INSERT INTO weather_data (location_id, temperature)
        VALUES ((SELECT location_id FROM locations WHERE latitude = ? AND longitude = ?), ?);
    """
    cursor.execute(insert_query, (latitude, longitude, temperature))
    
    conn.commit()
    conn.close()

# 示例使用
latitude, longitude = 39.7456, -97.0892  # 示例坐标
store_weather_data(latitude, longitude)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/dell/Documents/510lab4/data.ipynb 单元格 6 line <cell line: 41>()
#      <a href='vscode-notebook-cell:/Users/dell/Documents/510lab4/data.ipynb#W5sZmlsZQ%3D%3D?line=38'>39</a> # 示例使用
#      <a href='vscode-notebook-cell:/Users/dell/Documents/510lab4/data.ipynb#W5sZmlsZQ%3D%3D?line=39'>40</a> latitude, longitude = 39.7456, -97.0892  # 示例坐标
# ---> <a href='vscode-notebook-cell:/Users/dell/Documents/510lab4/data.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a> store_weather_data(latitude, longitude)
#
# /Users/dell/Documents/510lab4/data.ipynb 单元格 6 line store_weather_data(latitude, longitude)
#      <a href='vscode-notebook-cell:/Users/dell/Documents/510lab4/data.ipynb#W5sZmlsZQ%3D%3D?line=26'>27</a> # 插入数据到weather_data表
# ...
